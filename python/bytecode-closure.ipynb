# %%
def describe_func_closure(func):
    print(func.__name__, ': ')
    code = func.__code__
    print('\t cells: ', end='')
    if func.__closure__ is not None:
        for cell in func.__closure__:
            print(cell.cell_contents, end=' ')
    print()
    for name in dir(code):
        if name in ('co_cellvars', 'co_freevars'):
            print('\t', name, ': ', getattr(code, name))

# %%
def foo():
    x, y = (1, 2)
    def bar1():
        print(x)
    
    def bar2():
        print(x, y)
    
    return bar1, bar2

b1, b2 = foo()
describe_func_closure(foo)
describe_func_closure(b1)
describe_func_closure(b2)
# Out:
# foo :
# 	 cells:
# 	 co_cellvars :  ('x', 'y')
# 	 co_freevars :  ()
# bar1 :
# 	 cells: 1
# 	 co_cellvars :  ()
# 	 co_freevars :  ('x',)
# bar2 :
# 	 cells: 1 2
# 	 co_cellvars :  ()
# 	 co_freevars :  ('x', 'y')

# %%
def foo():
    x = 1
    def adder():
        nonlocal x
        x += 1
    
    def printer():
        print(x)
    
    return adder, printer

adder, printer = foo()
describe_func_closure(foo)
describe_func_closure(adder)
describe_func_closure(printer)
print('---------------------------')
print('adder()')
print('---------------------------')
adder()
describe_func_closure(adder)
describe_func_closure(printer)
print('---------------------------')
print('new')
print('---------------------------')
adder, printer = foo()
describe_func_closure(adder)
describe_func_closure(printer)
# Out:
# foo :
# 	 cells:
# 	 co_cellvars :  ('x',)
# 	 co_freevars :  ()
# adder :
# 	 cells: 1
# 	 co_cellvars :  ()
# 	 co_freevars :  ('x',)
# printer :
# 	 cells: 1
# 	 co_cellvars :  ()
# 	 co_freevars :  ('x',)
# ---------------------------
# adder()
# ---------------------------
# adder :
# 	 cells: 2
# 	 co_cellvars :  ()
# 	 co_freevars :  ('x',)
# printer :
# 	 cells: 2
# 	 co_cellvars :  ()
# 	 co_freevars :  ('x',)
# ---------------------------
# new
# ---------------------------
# adder :
# 	 cells: 1
# 	 co_cellvars :  ()
# 	 co_freevars :  ('x',)
# printer :
# 	 cells: 1
# 	 co_cellvars :  ()
# 	 co_freevars :  ('x',)

# %%
import dis

def foo():
    x, y = (1, 2)
    def bar1():
        print(x)
    
    def bar2():
        print(x, y)
    
    x += 1
    print(x, y)
    
    return bar1, bar2

b1, b2 = foo()
dis.dis(foo)
# Out:
# 2 2
#   4           0 LOAD_CONST               1 ((1, 2))
#               2 UNPACK_SEQUENCE          2
#               4 STORE_DEREF              0 (x)
#               6 STORE_DEREF              1 (y)
#
#   5           8 LOAD_CLOSURE             0 (x)
#              10 BUILD_TUPLE              1
#              12 LOAD_CONST               2 (<code object bar1 at 0x108c4f660, file "/var/folders/90/l75jsw6n1_g9z2yr07xqwzcw0000gn/T/ipykernel_86181/1494465118.py", line 5>)
#              14 LOAD_CONST               3 ('foo.<locals>.bar1')
#              16 MAKE_FUNCTION            8 (closure)
#              18 STORE_FAST               0 (bar1)
#
#   8          20 LOAD_CLOSURE             0 (x)
#              22 LOAD_CLOSURE             1 (y)
#              24 BUILD_TUPLE              2
#              26 LOAD_CONST               4 (<code object bar2 at 0x108c4f450, file "/var/folders/90/l75jsw6n1_g9z2yr07xqwzcw0000gn/T/ipykernel_86181/1494465118.py", line 8>)
#              28 LOAD_CONST               5 ('foo.<locals>.bar2')
#              30 MAKE_FUNCTION            8 (closure)
#              32 STORE_FAST               1 (bar2)
#
#  11          34 LOAD_DEREF               0 (x)
#              36 LOAD_CONST               6 (1)
#              38 INPLACE_ADD
#              40 STORE_DEREF              0 (x)
#
#  12          42 LOAD_GLOBAL              0 (print)
#              44 LOAD_DEREF               0 (x)
#              46 LOAD_DEREF               1 (y)
#              48 CALL_FUNCTION            2
#              50 POP_TOP
#
#  14          52 LOAD_FAST                0 (bar1)
#              54 LOAD_FAST                1 (bar2)
#              56 BUILD_TUPLE              2
#              58 RETURN_VALUE
#
# Disassembly of <code object bar1 at 0x108c4f660, file "/var/folders/90/l75jsw6n1_g9z2yr07xqwzcw0000gn/T/ipykernel_86181/1494465118.py", line 5>:
#   6           0 LOAD_GLOBAL              0 (print)
#               2 LOAD_DEREF               0 (x)
#               4 CALL_FUNCTION            1
#               6 POP_TOP
#               8 LOAD_CONST               0 (None)
#              10 RETURN_VALUE
#
# Disassembly of <code object bar2 at 0x108c4f450, file "/var/folders/90/l75jsw6n1_g9z2yr07xqwzcw0000gn/T/ipykernel_86181/1494465118.py", line 8>:
#   9           0 LOAD_GLOBAL              0 (print)
#               2 LOAD_DEREF               0 (x)
#               4 LOAD_DEREF               1 (y)
#               6 CALL_FUNCTION            2
#               8 POP_TOP
#              10 LOAD_CONST               0 (None)
#              12 RETURN_VALUE

# %%
import dis

def foo(x):
    y = 1
    print(x, y)

    def bar1():
        print(x)
    
    def bar2():
        print(x, y)
        z = 3

        def bar3():
            print(z)

        return bar3
    
    x += 1
    print(x, y)
    
    return bar1, bar2

b1, b2 = foo(1)
dis.dis(foo)
# Out:
# 1 1
# 2 1
#   4           0 LOAD_CONST               1 (1)
#               2 STORE_DEREF              1 (y)
#
#   5           4 LOAD_GLOBAL              0 (print)
#               6 LOAD_DEREF               0 (x)
#               8 LOAD_DEREF               1 (y)
#              10 CALL_FUNCTION            2
#              12 POP_TOP
#
#   7          14 LOAD_CLOSURE             0 (x)
#              16 BUILD_TUPLE              1
#              18 LOAD_CONST               2 (<code object bar1 at 0x108c0bea0, file "/var/folders/90/l75jsw6n1_g9z2yr07xqwzcw0000gn/T/ipykernel_86181/2439059404.py", line 7>)
#              20 LOAD_CONST               3 ('foo.<locals>.bar1')
#              22 MAKE_FUNCTION            8 (closure)
#              24 STORE_FAST               1 (bar1)
#
#  10          26 LOAD_CLOSURE             0 (x)
#              28 LOAD_CLOSURE             1 (y)
#              30 BUILD_TUPLE              2
#              32 LOAD_CONST               4 (<code object bar2 at 0x108c0bdf0, file "/var/folders/90/l75jsw6n1_g9z2yr07xqwzcw0000gn/T/ipykernel_86181/2439059404.py", line 10>)
#              34 LOAD_CONST               5 ('foo.<locals>.bar2')
#              36 MAKE_FUNCTION            8 (closure)
#              38 STORE_FAST               2 (bar2)
#
#  19          40 LOAD_DEREF               0 (x)
#              42 LOAD_CONST               1 (1)
#              44 INPLACE_ADD
#              46 STORE_DEREF              0 (x)
#
#  20          48 LOAD_GLOBAL              0 (print)
#              50 LOAD_DEREF               0 (x)
#              52 LOAD_DEREF               1 (y)
#              54 CALL_FUNCTION            2
#              56 POP_TOP
#
#  22          58 LOAD_FAST                1 (bar1)
#              60 LOAD_FAST                2 (bar2)
#              62 BUILD_TUPLE              2
#              64 RETURN_VALUE
#
# Disassembly of <code object bar1 at 0x108c0bea0, file "/var/folders/90/l75jsw6n1_g9z2yr07xqwzcw0000gn/T/ipykernel_86181/2439059404.py", line 7>:
#   8           0 LOAD_GLOBAL              0 (print)
#               2 LOAD_DEREF               0 (x)
#               4 CALL_FUNCTION            1
#               6 POP_TOP
#               8 LOAD_CONST               0 (None)
#              10 RETURN_VALUE
#
# Disassembly of <code object bar2 at 0x108c0bdf0, file "/var/folders/90/l75jsw6n1_g9z2yr07xqwzcw0000gn/T/ipykernel_86181/2439059404.py", line 10>:
#  11           0 LOAD_GLOBAL              0 (print)
#               2 LOAD_DEREF               1 (x)
#               4 LOAD_DEREF               2 (y)
#               6 CALL_FUNCTION            2
#               8 POP_TOP
#
#  12          10 LOAD_CONST               1 (3)
#              12 STORE_DEREF              0 (z)
#
#  14          14 LOAD_CLOSURE             0 (z)
#              16 BUILD_TUPLE              1
#              18 LOAD_CONST               2 (<code object bar3 at 0x108c0b660, file "/var/folders/90/l75jsw6n1_g9z2yr07xqwzcw0000gn/T/ipykernel_86181/2439059404.py", line 14>)
#              20 LOAD_CONST               3 ('foo.<locals>.bar2.<locals>.bar3')
#              22 MAKE_FUNCTION            8 (closure)
#              24 STORE_FAST               0 (bar3)
#
#  17          26 LOAD_FAST                0 (bar3)
#              28 RETURN_VALUE
#
# Disassembly of <code object bar3 at 0x108c0b660, file "/var/folders/90/l75jsw6n1_g9z2yr07xqwzcw0000gn/T/ipykernel_86181/2439059404.py", line 14>:
#  15           0 LOAD_GLOBAL              0 (print)
#               2 LOAD_DEREF               0 (z)
#               4 CALL_FUNCTION            1
#               6 POP_TOP
#               8 LOAD_CONST               0 (None)
#              10 RETURN_VALUE

# %%
def foo():
    x, y = (1, 2)
    def bar1():
        z = 3 
        print(x)
        
        def bar3():
            print(z)
        
        return bar3
    
    def bar2():
        print(x, y)
    
    return bar1, bar2

b1, b2 = foo()
b3 = b1()
describe_func_closure(b1)
describe_func_closure(b2)
describe_func_closure(b3)
describe_func_closure(foo)
# Out:
# 1
# bar1 :
# 	 cells: 1
# 	 co_cellvars :  ('z',)
# 	 co_freevars :  ('x',)
# bar2 :
# 	 cells: 1 2
# 	 co_cellvars :  ()
# 	 co_freevars :  ('x', 'y')
# bar3 :
# 	 cells: 3
# 	 co_cellvars :  ()
# 	 co_freevars :  ('z',)
# foo :
# 	 cells:
# 	 co_cellvars :  ('x', 'y')
# 	 co_freevars :  ()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 23
#      21 describe_func_closure(b3)
#      22 describe_func_closure(foo)
# ---> 23 print(z)
#
# NameError: name 'z' is not defined

# %%
def foo(x):
    y = 2
    def bar():
        nonlocal y
        print(x, y)
        y += 1
    return bar

dis.dis(foo)
# Out:
#   2           0 LOAD_CONST               1 (2)
#               2 STORE_DEREF              1 (y)
#
#   3           4 LOAD_CLOSURE             0 (x)
#               6 LOAD_CLOSURE             1 (y)
#               8 BUILD_TUPLE              2
#              10 LOAD_CONST               2 (<code object bar at 0x101b847c0, file "/var/folders/90/l75jsw6n1_g9z2yr07xqwzcw0000gn/T/ipykernel_86181/1646305308.py", line 3>)
#              12 LOAD_CONST               3 ('foo.<locals>.bar')
#              14 MAKE_FUNCTION            8 (closure)
#              16 STORE_FAST               1 (bar)
#
#   7          18 LOAD_FAST                1 (bar)
#              20 RETURN_VALUE
#
# Disassembly of <code object bar at 0x101b847c0, file "/var/folders/90/l75jsw6n1_g9z2yr07xqwzcw0000gn/T/ipykernel_86181/1646305308.py", line 3>:
#   5           0 LOAD_GLOBAL              0 (print)
#               2 LOAD_DEREF               0 (x)
#               4 LOAD_DEREF               1 (y)
#               6 CALL_FUNCTION            2
#               8 POP_TOP
#
#   6          10 LOAD_DEREF               1 (y)
#              12 LOAD_CONST               1 (1)
#              14 INPLACE_ADD
#              16 STORE_DEREF              1 (y)
#              18 LOAD_CONST               0 (None)
#              20 RETURN_VALUE
